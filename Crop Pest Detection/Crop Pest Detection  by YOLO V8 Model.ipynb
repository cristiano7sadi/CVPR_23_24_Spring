# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.8/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QhiVsxjWDFykgB9aRaDg")
project = rf.workspace("tini").project("pest-detection-0sv8g")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=30 imgsz=600 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.2.17 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					    labels.jpg	      train_batch2.jpg
# events.out.tfevents.1715971525.37e835da9c27.1307.0  train_batch0.jpg  weights
# labels_correlogram.jpg				    train_batch1.jpg

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/content/pest-3.jpeg save=True
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/pest-3.jpeg: 608x608 1 Gall.Flies, 26.3ms
# Speed: 4.8ms preprocess, 26.3ms inference, 862.4ms postprocess per image at shape (1, 3, 608, 608)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/predict3/pest-3.jpeg', width=600)
# Out:
# /content

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/content/pest-2.jpeg save=True
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/pest-2.jpeg: 384x608 (no detections), 131.6ms
# Speed: 3.0ms preprocess, 131.6ms inference, 27.1ms postprocess per image at shape (1, 3, 384, 608)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/predict2/pest-2.jpeg', width=600)
# Out:
# /content

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train2/")
# Out:
# An error occured when getting the model upload URL: 404 Client Error: Not Found for url: https://api.roboflow.com/tini/pest-detection-0sv8g/5/uploadModel?api_key=QhiVsxjWDFykgB9aRaDg&modelType=yolov8&nocache=true

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/content/pest-6.jpg save=True
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/pest-6.jpg: 480x608 2 stem.Borers, 137.3ms
# Speed: 4.2ms preprocess, 137.3ms inference, 527.7ms postprocess per image at shape (1, 3, 480, 608)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/predict5/pest-6.jpg', width=600)
# Out:
# /content

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/content/pest-7.jpg save=True
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/pest-7.jpg: 320x608 2 Locusts, 123.7ms
# Speed: 2.7ms preprocess, 123.7ms inference, 573.3ms postprocess per image at shape (1, 3, 320, 608)
# Results saved to runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/predict6/pest-7.jpg', width=600)
# Out:
# /content
